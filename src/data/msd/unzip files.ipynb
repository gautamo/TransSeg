# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
# !cd /gdrive/MyDrive/TransSeg/src/data/msd
# !ls /gdrive/MyDrive/TransSeg/src/data/msd
# Out:
#  processed		       Task05_Prostate.tar
#  split_data_to_slices_nii.py   Task06_Lung
#  Task01_BrainTumour	       Task06_Lung.tar
#  Task01_BrainTumour.tar        Task07_Pancreas
#  Task02_Heart		       Task07_Pancreas.tar
#  Task02_Heart.tar	       Task08_HepaticVessel
#  Task03_Liver		       Task08_HepaticVessel.tar
#  Task03_Liver.tar	       Task09_Spleen
#  Task04_Hippocampus	       Task10_Colon
#  Task04_Hippocampus.tar        Task10_Colon.tar
#  Task05_Prostate	      'unzip files.ipynb'

# %%
# %%bash
# untar_if_not_exist() {
#     if [ ! -d "$1$2" ]; then
#         echo "Extracting $1$2.tar..."
#         tar -xvf "$1$2.tar"
#         mv $2 $1$2
#     else
#         echo "$1$2 directory already exists."
#     fi
# }
#
# untar_if_not_exist /gdrive/MyDrive/TransSeg/src/data/msd/ Task01_BrainTumour
# Out:
# /gdrive/MyDrive/TransSeg/src/data/msd/Task01_BrainTumour directory already exists.

# %%
# %%bash
# untar_if_not_exist() {
#     if [ ! -d "$1$2" ]; then
#         echo "Extracting $1$2.tar..."
#         tar -xvf "$1$2.tar"
#         mv $2 $1$2
#     else
#         echo "$1$2 directory already exists."
#     fi
# }
#
# untar_if_not_exist /gdrive/MyDrive/TransSeg/src/data/msd/ Task02_Heart
# Out:
# /gdrive/MyDrive/TransSeg/src/data/msd/Task02_Heart directory already exists.

# %%
# %%bash
# untar_if_not_exist() {
#     if [ ! -d "$1$2" ]; then
#         echo "Extracting $1$2.tar..."
#         tar -xvf "$1$2.tar"
#         mv $2 $1$2
#     else
#         echo "$1$2 directory already exists."
#     fi
# }
#
# untar_if_not_exist /gdrive/MyDrive/TransSeg/src/data/msd/ Task03_Liver
# Out:
# /gdrive/MyDrive/TransSeg/src/data/msd/Task03_Liver directory already exists.

# %%
# %%bash
# untar_if_not_exist() {
#     if [ ! -d "$1$2" ]; then
#         echo "Extracting $1$2.tar..."
#         tar -xvf "$1$2.tar"
#         mv $2 $1$2
#     else
#         echo "$1$2 directory already exists."
#     fi
# }
#
# untar_if_not_exist /gdrive/MyDrive/TransSeg/src/data/msd/ Task04_Hippocampus
# Out:
# /gdrive/MyDrive/TransSeg/src/data/msd/Task04_Hippocampus directory already exists.

# %%
# %%bash
# untar_if_not_exist() {
#     if [ ! -d "$1$2" ]; then
#         echo "Extracting $1$2.tar..."
#         tar -xvf "$1$2.tar"
#         mv $2 $1$2
#     else
#         echo "$1$2 directory already exists."
#     fi
# }
#
# untar_if_not_exist /gdrive/MyDrive/TransSeg/src/data/msd/ Task05_Prostate
# Out:
# /gdrive/MyDrive/TransSeg/src/data/msd/Task05_Prostate directory already exists.

# %%
# %%bash
# untar_if_not_exist() {
#     if [ ! -d "$1$2" ]; then
#         echo "Extracting $1$2.tar..."
#         tar -xvf "$1$2.tar"
#         mv $2 $1$2
#     else
#         echo "$1$2 directory already exists."
#     fi
# }
#
# untar_if_not_exist /gdrive/MyDrive/TransSeg/src/data/msd/ Task06_Lung
# Out:
# /gdrive/MyDrive/TransSeg/src/data/msd/Task06_Lung directory already exists.

# %%
# %%bash
# untar_if_not_exist() {
#     if [ ! -d "$1$2" ]; then
#         echo "Extracting $1$2.tar..."
#         tar -xvf "$1$2.tar"
#         mv $2 $1$2
#     else
#         echo "$1$2 directory already exists."
#     fi
# }
#
# untar_if_not_exist /gdrive/MyDrive/TransSeg/src/data/msd/ Task07_Pancreas
# Out:
# /gdrive/MyDrive/TransSeg/src/data/msd/Task07_Pancreas directory already exists.

# %%
# %%bash
# untar_if_not_exist() {
#     if [ ! -d "$1$2" ]; then
#         echo "Extracting $1$2.tar..."
#         tar -xvf "$1$2.tar"
#         mv $2 $1$2
#     else
#         echo "$1$2 directory already exists."
#     fi
# }
#
# untar_if_not_exist /gdrive/MyDrive/TransSeg/src/data/msd/ Task08_HepaticVessel
# Out:
# /gdrive/MyDrive/TransSeg/src/data/msd/Task08_HepaticVessel directory already exists.

# %%
# %%bash
# untar_if_not_exist() {
#     if [ ! -d "$1$2" ]; then
#         echo "Extracting $1$2.tar..."
#         tar -xvf "$1$2.tar"
#         mv $2 $1$2
#     else
#         echo "$1$2 directory already exists."
#     fi
# }
#
# untar_if_not_exist /gdrive/MyDrive/TransSeg/src/data/msd/ Task10_Colon
# Out:
# /gdrive/MyDrive/TransSeg/src/data/msd/Task10_Colon directory already exists.

# %%
# %cd /gdrive/MyDrive/TransSeg/src/data/msd/
# !python3 split_data_to_slices_nii.py
# %cd /content/
# Out:
# /gdrive/MyDrive/TransSeg/src/data/msd
# Task07_Pancreas 224 42 15 139
# GB Processing 0/420: {'image': './imagesTr/pancreas_215.nii.gz', 'label': './labelsTr/pancreas_215.nii.gz', 'split': 'training'}
# training {'image': './imagesTr/pancreas_215.nii.gz', 'label': './labelsTr/pancreas_215.nii.gz', 'split': 'training'} (512, 512, 99) (512, 512, 99) (-522.8596516233501, 501.5903964437557, -1024.0, 3071.0) (0.001963952575067077, 0.045171604288505, 0.0, 2.0)
# GB Processing 1/420: {'image': './imagesTr/pancreas_109.nii.gz', 'label': './labelsTr/pancreas_109.nii.gz', 'split': 'training'}
# training {'image': './imagesTr/pancreas_109.nii.gz', 'label': './labelsTr/pancreas_109.nii.gz', 'split': 'training'} (512, 512, 99) (512, 512, 99) (-485.0624508713231, 498.9170385833718, -1024.0, 1704.0) (0.0033279187751538825, 0.058512668028461265, 0.0, 2.0)
# GB Processing 2/420: {'image': './imagesTr/pancreas_308.nii.gz', 'label': './labelsTr/pancreas_308.nii.gz', 'split': 'training'}
# ...
